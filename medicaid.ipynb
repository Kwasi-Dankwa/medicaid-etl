# %% [markdown]
# <a href="https://colab.research.google.com/github/Kwasi-Dankwa/medicaid-etl/blob/main/medicaid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Extraction**

# %%
import requests
import pandas as pd

# Extraction
api_url = 'https://data.cms.gov/data-api/v1/dataset/be64fce3-e835-4589-b46b-024198e524a6/data'
response = requests.get(api_url)
data = response.json()

# %% [markdown]
# Transformation

# %%
# Transformation (converting JSON to DataFrame)
df = pd.DataFrame(data)

# Cleaning data
df.shape
df.info()
df.head()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Brnd_Name                        1000 non-null   object
#  1   Gnrc_Name                        1000 non-null   object
#  2   Tot_Mftr                         1000 non-null   object
#  3   Mftr_Name                        1000 non-null   object
#  4   Tot_Spndng_2018                  1000 non-null   object
#  5   Tot_Dsg_Unts_2018                1000 non-null   object
#  6   Tot_Clms_2018                    1000 non-null   object
#  7   Avg_Spnd_Per_Dsg_Unt_Wghtd_2018  1000 non-null   object
#  8   Avg_Spnd_Per_Clm_2018            1000 non-null   object
#  9   Outlier_Flag_2018                1000 non-null   object
#  10  Tot_Spndng_2019                  1000 non-null   object
#  11  Tot_Dsg_Unts_2019                1000 non-null   object
#  12  Tot_Clms_2019                    1000 non-null   object
#  13  Avg_Spnd_Per_Dsg_Unt_Wghtd_2019  1000 non-null   object
#  14  Avg_Spnd_Per_Clm_2019            1000 non-null   object
#  15  Outlier_Flag_2019                1000 non-null   object
#  16  Tot_Spndng_2020                  1000 non-null   object
#  17  Tot_Dsg_Unts_2020                1000 non-null   object
#  18  Tot_Clms_2020                    1000 non-null   object
#  19  Avg_Spnd_Per_Dsg_Unt_Wghtd_2020  1000 non-null   object
#  20  Avg_Spnd_Per_Clm_2020            1000 non-null   object
#  21  Outlier_Flag_2020                1000 non-null   object
#  22  Tot_Spndng_2021                  1000 non-null   object
#  23  Tot_Dsg_Unts_2021                1000 non-null   object
#  24  Tot_Clms_2021                    1000 non-null   object
#  25  Avg_Spnd_Per_Dsg_Unt_Wghtd_2021  1000 non-null   object
#  26  Avg_Spnd_Per_Clm_2021            1000 non-null   object
#  27  Outlier_Flag_2021                1000 non-null   object
#  28  Tot_Spndng_2022                  1000 non-null   object
#  29  Tot_Dsg_Unts_2022                1000 non-null   object
#  30  Tot_Clms_2022                    1000 non-null   object
#  31  Avg_Spnd_Per_Dsg_Unt_Wghtd_2022  1000 non-null   object
#  32  Avg_Spnd_Per_Clm_2022            1000 non-null   object
#  33  Outlier_Flag_2022                1000 non-null   object
#  34  Chg_Avg_Spnd_Per_Dsg_Unt_21_22   1000 non-null   object
#  35  CAGR_Avg_Spnd_Per_Dsg_Unt_18_22  1000 non-null   object
# dtypes: object(36)
# memory usage: 281.4+ KB
#          Brnd_Name     Gnrc_Name Tot_Mftr Mftr_Name Tot_Spndng_2018  \
# count         1000          1000     1000      1000            1000
# unique         262           219       20       250             581
# top     Acyclovir*  Aripiprazole        1   Overall
# freq            34            34      925       269             264
#
#        Tot_Dsg_Unts_2018 Tot_Clms_2018 Avg_Spnd_Per_Dsg_Unt_Wghtd_2018  \
# count               1000          1000                            1000
# unique               578           549                             581
# top
# freq                 264           264                             264
#
#        Avg_Spnd_Per_Clm_2018 Outlier_Flag_2018  ... Avg_Spnd_Per_Clm_2021  \
# count                   1000              1000  ...                  1000
# unique                   581                 3  ...                   751
# top                                          0  ...
# freq                     264               491  ...                    61
#
#        Outlier_Flag_2021 Tot_Spndng_2022 Tot_Dsg_Unts_2022 Tot_Clms_2022  \
# count               1000            1000              1000          1000
# unique                 3             807               800           688
# top                    0      2632099.12               690            17
# freq                 601               2                 3            13
#
#        Avg_Spnd_Per_Dsg_Unt_Wghtd_2022 Avg_Spnd_Per_Clm_2022  \
# count                             1000                  1000
# unique                             807                   807
# top                       11.212483995          334.83006233
# freq                                 2                     2
#
#        Outlier_Flag_2022 Chg_Avg_Spnd_Per_Dsg_Unt_21_22  \
# count               1000                           1000
# unique                 2                            840
# top                    0
# freq                 597                             61
#
#        CAGR_Avg_Spnd_Per_Dsg_Unt_18_22
# count                             1000
# unique                             762
# top                                  0
# freq                                52
#
# [4 rows x 36 columns]

# %%
# Standardizing column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
#fixing datatypes
# Ensure spending columns are numeric
spending_cols = [col for col in df.columns if 'spndng' in col]
df[spending_cols] = df[spending_cols].apply(pd.to_numeric, errors='coerce')


# Ensure avg columns are numeric
avg_cols = [col for col in df.columns if 'avg' in col]
df[avg_cols] = df[avg_cols].apply(pd.to_numeric, errors='coerce')

# Ensure tot columns are numeric
tot_cols = [col for col in df.columns if 'tot' in col]
df[tot_cols] = df[tot_cols].apply(pd.to_numeric, errors='coerce')

#ensure outlier columns are numberic
outlier_cols = [col for col in df.columns if 'outlier' in col]
df[outlier_cols] = df[outlier_cols].apply(pd.to_numeric, errors='coerce')

# %%
#Finding missing data
df.isnull().sum()

# Drop columns with "outlier" in the column header
df = df.drop(columns=[col for col in df.columns if 'outlier' in col])

# %% [markdown]
# Load Phase

# %%
# Save cleaned dataset as csv
df.to_csv('medicaid_drug_spending_clean.csv', index=False)
